# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1, 2, 3"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from Net import Tomography_CNN
from DataLoader import Dataset
from SSIM import SSIM
from torch.optim.lr_scheduler import MultiplicativeLR
import time
import copy

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.13.0  Device: cuda

# %%
N=40000

train_id = np.arange(0,32000)
validation_id = np.arange(32000,36000)
test_id = np.arange(36000,N)

len(train_id), len(validation_id), len(test_id)
# Out:
# (32000, 4000, 4000)

# %%
n_gpus = 4
learning_rate = 5.0e-4 * n_gpus

BATCH_SIZE = 20 * n_gpus
EPOCHS = 200

# %%
train_dataset = Dataset(train_id, nshot=200, nx=320, ny=50)
val_dataset = Dataset(validation_id, nshot=200, nx=320, ny=50)
test_dataset = Dataset(test_id, nshot=200, nx=320, ny=50)

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           num_workers=4 * n_gpus, 
                                           pin_memory=True,
                                           shuffle = True)
val_loader = torch.utils.data.DataLoader(dataset = val_dataset,
                                         batch_size = BATCH_SIZE,
                                         num_workers=4 * n_gpus, 
                                         pin_memory=True,
                                         shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          num_workers=4 * n_gpus, 
                                          pin_memory=True,
                                          shuffle = False)

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([80, 1, 320, 200]) type: torch.FloatTensor
# y_train: torch.Size([80, 1, 320, 50]) type: torch.FloatTensor

# %%
model = torch.nn.DataParallel(Tomography_CNN().cuda(), device_ids=[0, 1, 2, 3])
#model = Tomography_CNN().cuda()

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, amsgrad=True)
scheduler = MultiplicativeLR(optimizer, lr_lambda = lambda epoch:0.95)

ssim = SSIM()

# %%
def train_model(model, optimizer, scheduler, num_epochs=None):

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1.0
    train_losses, train_mae_losses, train_mse_losses, train_ssim_losses = [],[],[],[]
    val_losses, val_mae_losses, val_mse_losses, val_ssim_losses = [],[],[],[]

    for epoch in range(num_epochs):
        since = time.time()
        print('\nEpoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # 각 Epoch은 학습 단계와 검증 단계를 거침
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # 학습 모드 설정
                train_mae = 0.0
                train_mse = 0.0
                train_ssim = 0.0
                train_loss = 0.0
                
                for image, label in train_loader:
                    image, label = image.cuda(), label.cuda()
                    optimizer.zero_grad()
                    output = model(image)
                    mae_loss = F.l1_loss(output, label)
                    mse_loss = F.mse_loss(output, label)
                    ssim_loss = ssim(output, label)
                    loss = mae_loss + mse_loss + (1 - ssim_loss)
                    
                    train_mae += mae_loss.detach()
                    train_mse += mse_loss.detach()
                    train_ssim += ssim_loss.detach()
                    train_loss += loss.detach()
                    
                    loss.backward()
                    optimizer.step()
                
                scheduler.step()
                epoch_train_mae = train_mae / len(train_loader.dataset) * BATCH_SIZE
                epoch_train_mse = train_mse / len(train_loader.dataset) * BATCH_SIZE
                epoch_train_ssim = train_ssim / len(train_loader.dataset) * BATCH_SIZE
                epoch_train_loss = train_loss / len(train_loader.dataset) * BATCH_SIZE
                train_mae_losses.append(epoch_train_mae.cpu())
                train_mse_losses.append(epoch_train_mse.cpu())
                train_ssim_losses.append(epoch_train_ssim.cpu())
                train_losses.append(epoch_train_loss.cpu())
                print('{} Loss: {:.4f} MAE: {:.4f} MSE {:.4f} SSIM {:.4f}'.format(
                    phase, epoch_train_loss, epoch_train_mae, epoch_train_mse, epoch_train_ssim))
                
                time_elapsed = time.time() - since
                
            else:
                model.eval()  # 검증 모드 설정
                val_mae = 0.0
                val_mse = 0.0
                val_ssim = 0.0
                val_loss = 0.0
                
                for image, label in val_loader:
                    image, label = image.cuda(), label.cuda()
                    output = model(image)
                    mae_loss = F.l1_loss(output, label)
                    mse_loss = F.mse_loss(output, label)
                    ssim_loss = ssim(output, label)
                    loss = mae_loss + mse_loss + (1 - ssim_loss)
                    
                    val_mae += mae_loss.detach()
                    val_mse += mse_loss.detach()
                    val_ssim += ssim_loss.detach()
                    val_loss += loss.detach()
                    
                epoch_val_mae = val_mae / len(val_loader.dataset) * BATCH_SIZE
                epoch_val_mse = val_mse / len(val_loader.dataset) * BATCH_SIZE
                epoch_val_ssim = val_ssim / len(val_loader.dataset) * BATCH_SIZE
                epoch_val_loss = val_loss / len(val_loader.dataset) * BATCH_SIZE
                val_mae_losses.append(epoch_val_mae.cpu())
                val_mse_losses.append(epoch_val_mse.cpu())
                val_ssim_losses.append(epoch_val_ssim.cpu())
                val_losses.append(epoch_val_loss.cpu())
                print('{} Loss: {:.4f} MAE: {:.4f} MSE {:.4f} SSIM {:.4f}'.format(
                    phase, epoch_val_loss, epoch_val_mae, epoch_val_mse, epoch_val_ssim))
                print('Training time elapesd per epoch {:.0f}m {:.0f}s'.format(
                    time_elapsed // 60, time_elapsed % 60))
            
            # 모델 복사(Deep Copy)
            if phase == 'valid' and epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_model_wts = copy.deepcopy(model.state_dict())


    # 최적의 모델 가중치 로딩
    model.load_state_dict(best_model_wts)
    return model, train_losses, train_mae_losses, train_mse_losses, train_ssim_losses, val_losses, val_mae_losses, val_mse_losses, val_ssim_losses

# %%
model_ft, train_losses, train_mae_losses, train_mse_losses, train_ssim_losses, val_losses, val_mae_losses, val_mse_losses, val_ssim_losses = train_model(
    model, optimizer, scheduler, num_epochs=EPOCHS)
# Out:
# Epoch 1/200
# ----------
# train Loss: 0.6385 MAE: 0.1878 MSE 0.1256 SSIM 0.6749
# valid Loss: 0.7891 MAE: 0.2269 MSE 0.1999 SSIM 0.6377
# Training time elapesd per epoch 2m 4s
#
# Epoch 2/200
# ----------
# train Loss: 0.4724 MAE: 0.1286 MSE 0.0651 SSIM 0.7213
# valid Loss: 0.9625 MAE: 0.3073 MSE 0.2756 SSIM 0.6205
# Training time elapesd per epoch 1m 56s
#
# Epoch 3/200
# ----------
# train Loss: 0.4283 MAE: 0.1144 MSE 0.0540 SSIM 0.7402
# valid Loss: 0.8326 MAE: 0.2507 MSE 0.2230 SSIM 0.6412
# Training time elapesd per epoch 1m 56s
#
# Epoch 4/200
# ----------
# train Loss: 0.3989 MAE: 0.1054 MSE 0.0472 SSIM 0.7537
# valid Loss: 0.4327 MAE: 0.1168 MSE 0.0570 SSIM 0.7411
# Training time elapesd per epoch 1m 56s
#
# Epoch 5/200
# ----------
# train Loss: 0.3829 MAE: 0.1005 MSE 0.0437 SSIM 0.7613
# valid Loss: 0.5783 MAE: 0.1712 MSE 0.1029 SSIM 0.6958
# Training time elapesd per epoch 1m 56s
#
# Epoch 6/200
# ----------
# train Loss: 0.3670 MAE: 0.0957 MSE 0.0402 SSIM 0.7690
# valid Loss: 1.1135 MAE: 0.3536 MSE 0.3589 SSIM 0.5989
# Training time elapesd per epoch 1m 56s
#
# Epoch 7/200
# ----------
# train Loss: 0.3569 MAE: 0.0928 MSE 0.0380 SSIM 0.7739
# valid Loss: 0.6144 MAE: 0.1945 MSE 0.1140 SSIM 0.6942
# Training time elapesd per epoch 1m 56s
#
# Epoch 8/200
# ----------
# train Loss: 0.3467 MAE: 0.0898 MSE 0.0359 SSIM 0.7790
# valid Loss: 0.4072 MAE: 0.1088 MSE 0.0560 SSIM 0.7576
# Training time elapesd per epoch 1m 56s
#
# Epoch 9/200
# ----------
# train Loss: 0.3399 MAE: 0.0877 MSE 0.0344 SSIM 0.7822
# valid Loss: 0.9376 MAE: 0.2690 MSE 0.2532 SSIM 0.5846
# Training time elapesd per epoch 1m 56s
#
# Epoch 10/200
# ----------
# train Loss: 0.3321 MAE: 0.0855 MSE 0.0328 SSIM 0.7862
# valid Loss: 0.4414 MAE: 0.1191 MSE 0.0627 SSIM 0.7404
# Training time elapesd per epoch 1m 56s
#
# Epoch 11/200
# ----------
# train Loss: 0.3275 MAE: 0.0841 MSE 0.0320 SSIM 0.7885
# valid Loss: 0.8762 MAE: 0.2616 MSE 0.2331 SSIM 0.6185
# Training time elapesd per epoch 1m 56s
#
# Epoch 12/200
# ----------
# train Loss: 0.3208 MAE: 0.0822 MSE 0.0305 SSIM 0.7919
# valid Loss: 0.3873 MAE: 0.1090 MSE 0.0445 SSIM 0.7662
# Training time elapesd per epoch 1m 55s
#
# Epoch 13/200
# ----------
# train Loss: 0.3154 MAE: 0.0807 MSE 0.0294 SSIM 0.7948
# valid Loss: 0.4855 MAE: 0.1475 MSE 0.0782 SSIM 0.7402
# Training time elapesd per epoch 1m 56s
#
# Epoch 14/200
# ----------
# train Loss: 0.3117 MAE: 0.0797 MSE 0.0287 SSIM 0.7967
# valid Loss: 0.6183 MAE: 0.1763 MSE 0.1208 SSIM 0.6788
# Training time elapesd per epoch 1m 56s
#
# Epoch 15/200
# ----------
# train Loss: 0.3079 MAE: 0.0784 MSE 0.0280 SSIM 0.7986
# valid Loss: 0.5144 MAE: 0.1458 MSE 0.0854 SSIM 0.7167
# Training time elapesd per epoch 1m 56s
#
# Epoch 16/200
# ----------
# train Loss: 0.3033 MAE: 0.0772 MSE 0.0271 SSIM 0.8010
# valid Loss: 0.6109 MAE: 0.1673 MSE 0.1304 SSIM 0.6868
# Training time elapesd per epoch 1m 56s
#
# Epoch 17/200
# ----------
# train Loss: 0.2978 MAE: 0.0756 MSE 0.0259 SSIM 0.8037
# valid Loss: 0.4107 MAE: 0.1119 MSE 0.0551 SSIM 0.7563
# Training time elapesd per epoch 1m 56s
#
# Epoch 18/200
# ----------
# train Loss: 0.2953 MAE: 0.0750 MSE 0.0254 SSIM 0.8051
# valid Loss: 0.3893 MAE: 0.1033 MSE 0.0453 SSIM 0.7593
# Training time elapesd per epoch 1m 56s
#
# Epoch 19/200
# ----------
# train Loss: 0.2931 MAE: 0.0743 MSE 0.0250 SSIM 0.8061
# valid Loss: 0.4738 MAE: 0.1288 MSE 0.0756 SSIM 0.7306
# Training time elapesd per epoch 1m 56s
#
# Epoch 20/200
# ----------
# train Loss: 0.2887 MAE: 0.0730 MSE 0.0241 SSIM 0.8084
# valid Loss: 0.4260 MAE: 0.1205 MSE 0.0604 SSIM 0.7549
# Training time elapesd per epoch 1m 56s
#
# Epoch 21/200
# ----------
# train Loss: 0.2871 MAE: 0.0726 MSE 0.0238 SSIM 0.8093
# valid Loss: 0.3375 MAE: 0.0890 MSE 0.0357 SSIM 0.7873
# Training time elapesd per epoch 1m 56s
#
# Epoch 22/200
# ----------
# train Loss: 0.2841 MAE: 0.0718 MSE 0.0231 SSIM 0.8108
# valid Loss: 0.4386 MAE: 0.1208 MSE 0.0580 SSIM 0.7402
# Training time elapesd per epoch 1m 56s
#
# Epoch 23/200
# ----------
# train Loss: 0.2818 MAE: 0.0712 MSE 0.0227 SSIM 0.8121
# valid Loss: 0.4024 MAE: 0.1046 MSE 0.0531 SSIM 0.7553
# Training time elapesd per epoch 1m 56s
#
# Epoch 24/200
# ----------
# train Loss: 0.2783 MAE: 0.0702 MSE 0.0219 SSIM 0.8138
# valid Loss: 0.3200 MAE: 0.0825 MSE 0.0336 SSIM 0.7961
# Training time elapesd per epoch 1m 56s
#
# Epoch 25/200
# ----------
# train Loss: 0.2761 MAE: 0.0696 MSE 0.0215 SSIM 0.8150
# valid Loss: 0.3335 MAE: 0.0896 MSE 0.0374 SSIM 0.7934
# Training time elapesd per epoch 1m 56s
#
# Epoch 26/200
# ----------
# train Loss: 0.2739 MAE: 0.0690 MSE 0.0211 SSIM 0.8163
# valid Loss: 0.3400 MAE: 0.0851 MSE 0.0381 SSIM 0.7833
# Training time elapesd per epoch 1m 56s
#
# Epoch 27/200
# ----------
# train Loss: 0.2725 MAE: 0.0686 MSE 0.0209 SSIM 0.8170
# valid Loss: 0.2944 MAE: 0.0736 MSE 0.0269 SSIM 0.8060
# Training time elapesd per epoch 1m 56s
#
# Epoch 28/200
# ----------
# train Loss: 0.2700 MAE: 0.0679 MSE 0.0204 SSIM 0.8183
# valid Loss: 0.3194 MAE: 0.0808 MSE 0.0313 SSIM 0.7927
# Training time elapesd per epoch 1m 56s
#
# Epoch 29/200
# ----------
# train Loss: 0.2677 MAE: 0.0674 MSE 0.0200 SSIM 0.8196
# valid Loss: 0.3029 MAE: 0.0746 MSE 0.0272 SSIM 0.7989
# Training time elapesd per epoch 1m 56s
#
# Epoch 30/200
# ----------
# train Loss: 0.2658 MAE: 0.0668 MSE 0.0196 SSIM 0.8206
# valid Loss: 0.3189 MAE: 0.0812 MSE 0.0335 SSIM 0.7958
# Training time elapesd per epoch 1m 56s
#
# Epoch 31/200
# ----------
# train Loss: 0.2636 MAE: 0.0663 MSE 0.0192 SSIM 0.8218
# valid Loss: 0.3892 MAE: 0.1108 MSE 0.0549 SSIM 0.7765
# Training time elapesd per epoch 1m 56s
#
# Epoch 32/200
# ----------
# train Loss: 0.2619 MAE: 0.0658 MSE 0.0189 SSIM 0.8228
# valid Loss: 0.3286 MAE: 0.0849 MSE 0.0345 SSIM 0.7908
# Training time elapesd per epoch 1m 56s
#
# Epoch 33/200
# ----------
# train Loss: 0.2608 MAE: 0.0655 MSE 0.0186 SSIM 0.8233
# valid Loss: 0.3133 MAE: 0.0808 MSE 0.0306 SSIM 0.7982
# Training time elapesd per epoch 1m 56s
#
# Epoch 34/200
# ----------
# train Loss: 0.2587 MAE: 0.0649 MSE 0.0183 SSIM 0.8245
# valid Loss: 0.3435 MAE: 0.0951 MSE 0.0383 SSIM 0.7899
# Training time elapesd per epoch 1m 56s
#
# Epoch 35/200
# ----------
# train Loss: 0.2576 MAE: 0.0647 MSE 0.0181 SSIM 0.8252
# valid Loss: 0.3227 MAE: 0.0830 MSE 0.0332 SSIM 0.7935
# Training time elapesd per epoch 1m 56s
#
# Epoch 36/200
# ----------
# train Loss: 0.2555 MAE: 0.0641 MSE 0.0177 SSIM 0.8263
# valid Loss: 0.3103 MAE: 0.0810 MSE 0.0323 SSIM 0.8030
# Training time elapesd per epoch 1m 56s
#
# Epoch 37/200
# ----------
# train Loss: 0.2540 MAE: 0.0637 MSE 0.0174 SSIM 0.8272
# valid Loss: 0.4019 MAE: 0.1128 MSE 0.0575 SSIM 0.7683
# Training time elapesd per epoch 1m 56s
#
# Epoch 38/200
# ----------
# train Loss: 0.2534 MAE: 0.0636 MSE 0.0174 SSIM 0.8277
# valid Loss: 0.4965 MAE: 0.1325 MSE 0.0925 SSIM 0.7284
# Training time elapesd per epoch 1m 56s
#
# Epoch 39/200
# ----------
# train Loss: 0.2519 MAE: 0.0632 MSE 0.0171 SSIM 0.8285
# valid Loss: 0.3729 MAE: 0.1029 MSE 0.0469 SSIM 0.7768
# Training time elapesd per epoch 1m 56s
#
# Epoch 40/200
# ----------
# train Loss: 0.2504 MAE: 0.0628 MSE 0.0168 SSIM 0.8292
# valid Loss: 0.4834 MAE: 0.1329 MSE 0.0806 SSIM 0.7302
# Training time elapesd per epoch 1m 56s
#
# Epoch 41/200
# ----------
# train Loss: 0.2491 MAE: 0.0625 MSE 0.0166 SSIM 0.8300
# valid Loss: 0.3081 MAE: 0.0805 MSE 0.0324 SSIM 0.8048
# Training time elapesd per epoch 1m 56s
#
# Epoch 42/200
# ----------
# train Loss: 0.2478 MAE: 0.0622 MSE 0.0164 SSIM 0.8308
# valid Loss: 0.3092 MAE: 0.0757 MSE 0.0279 SSIM 0.7945
# Training time elapesd per epoch 1m 56s
#
# Epoch 43/200
# ----------
# train Loss: 0.2467 MAE: 0.0618 MSE 0.0162 SSIM 0.8313
# valid Loss: 0.3422 MAE: 0.0927 MSE 0.0417 SSIM 0.7922
# Training time elapesd per epoch 1m 56s
#
# Epoch 44/200
# ----------
# train Loss: 0.2457 MAE: 0.0616 MSE 0.0161 SSIM 0.8320
# valid Loss: 0.3586 MAE: 0.0984 MSE 0.0446 SSIM 0.7844
# Training time elapesd per epoch 1m 56s
#
# Epoch 45/200
# ----------
# train Loss: 0.2450 MAE: 0.0614 MSE 0.0159 SSIM 0.8324
# valid Loss: 0.3124 MAE: 0.0829 MSE 0.0332 SSIM 0.8038
# Training time elapesd per epoch 1m 56s
#
# Epoch 46/200
# ----------
# train Loss: 0.2434 MAE: 0.0610 MSE 0.0156 SSIM 0.8333
# valid Loss: 0.3026 MAE: 0.0763 MSE 0.0305 SSIM 0.8043
# Training time elapesd per epoch 1m 56s
#
# Epoch 47/200
# ----------
# train Loss: 0.2422 MAE: 0.0607 MSE 0.0154 SSIM 0.8339
# valid Loss: 0.3014 MAE: 0.0737 MSE 0.0295 SSIM 0.8018
# Training time elapesd per epoch 1m 56s
#
# Epoch 48/200
# ----------
# train Loss: 0.2413 MAE: 0.0605 MSE 0.0153 SSIM 0.8345
# valid Loss: 0.3254 MAE: 0.0856 MSE 0.0353 SSIM 0.7955
# Training time elapesd per epoch 1m 56s
#
# Epoch 49/200
# ----------
# train Loss: 0.2407 MAE: 0.0604 MSE 0.0152 SSIM 0.8349
# valid Loss: 0.3133 MAE: 0.0787 MSE 0.0301 SSIM 0.7955
# Training time elapesd per epoch 1m 56s
#
# Epoch 50/200
# ----------
# train Loss: 0.2397 MAE: 0.0601 MSE 0.0151 SSIM 0.8355
# valid Loss: 0.2970 MAE: 0.0728 MSE 0.0277 SSIM 0.8035
# Training time elapesd per epoch 1m 56s
#
# Epoch 51/200
# ----------
# train Loss: 0.2388 MAE: 0.0599 MSE 0.0149 SSIM 0.8360
# valid Loss: 0.3100 MAE: 0.0758 MSE 0.0281 SSIM 0.7939
# Training time elapesd per epoch 1m 56s
#
# Epoch 52/200
# ----------
# train Loss: 0.2384 MAE: 0.0598 MSE 0.0149 SSIM 0.8362
# valid Loss: 0.2788 MAE: 0.0682 MSE 0.0250 SSIM 0.8144
# Training time elapesd per epoch 1m 56s
#
# Epoch 53/200
# ----------
# train Loss: 0.2376 MAE: 0.0596 MSE 0.0147 SSIM 0.8367
# valid Loss: 0.2851 MAE: 0.0700 MSE 0.0255 SSIM 0.8105
# Training time elapesd per epoch 1m 56s
#
# Epoch 54/200
# ----------
# train Loss: 0.2368 MAE: 0.0594 MSE 0.0146 SSIM 0.8372
# valid Loss: 0.3051 MAE: 0.0792 MSE 0.0314 SSIM 0.8055
# Training time elapesd per epoch 1m 56s
#
# Epoch 55/200
# ----------
# train Loss: 0.2357 MAE: 0.0591 MSE 0.0144 SSIM 0.8378
# valid Loss: 0.2789 MAE: 0.0692 MSE 0.0250 SSIM 0.8154
# Training time elapesd per epoch 1m 56s
#
# Epoch 56/200
# ----------
# train Loss: 0.2351 MAE: 0.0590 MSE 0.0143 SSIM 0.8382
# valid Loss: 0.2811 MAE: 0.0693 MSE 0.0262 SSIM 0.8143
# Training time elapesd per epoch 1m 56s
#
# Epoch 57/200
# ----------
# train Loss: 0.2347 MAE: 0.0589 MSE 0.0143 SSIM 0.8385
# valid Loss: 0.2839 MAE: 0.0696 MSE 0.0260 SSIM 0.8118
# Training time elapesd per epoch 1m 56s
#
# Epoch 58/200
# ----------
# train Loss: 0.2339 MAE: 0.0587 MSE 0.0142 SSIM 0.8389
# valid Loss: 0.3646 MAE: 0.0970 MSE 0.0455 SSIM 0.7778
# Training time elapesd per epoch 1m 56s
#
# Epoch 59/200
# ----------
# train Loss: 0.2335 MAE: 0.0586 MSE 0.0141 SSIM 0.8392
# valid Loss: 0.2773 MAE: 0.0677 MSE 0.0251 SSIM 0.8155
# Training time elapesd per epoch 1m 56s
#
# Epoch 60/200
# ----------
# train Loss: 0.2328 MAE: 0.0584 MSE 0.0140 SSIM 0.8396
# valid Loss: 0.2949 MAE: 0.0743 MSE 0.0276 SSIM 0.8070
# Training time elapesd per epoch 1m 56s
#
# Epoch 61/200
# ----------
# train Loss: 0.2323 MAE: 0.0583 MSE 0.0140 SSIM 0.8399
# valid Loss: 0.2826 MAE: 0.0689 MSE 0.0258 SSIM 0.8121
# Training time elapesd per epoch 1m 56s
#
# Epoch 62/200
# ----------
# train Loss: 0.2318 MAE: 0.0581 MSE 0.0139 SSIM 0.8402
# valid Loss: 0.2831 MAE: 0.0682 MSE 0.0256 SSIM 0.8107
# Training time elapesd per epoch 1m 56s
#
# Epoch 63/200
# ----------
# train Loss: 0.2310 MAE: 0.0579 MSE 0.0137 SSIM 0.8407
# valid Loss: 0.2781 MAE: 0.0675 MSE 0.0252 SSIM 0.8147
# Training time elapesd per epoch 1m 56s
#
# Epoch 64/200
# ----------
# train Loss: 0.2309 MAE: 0.0579 MSE 0.0137 SSIM 0.8408
# valid Loss: 0.2839 MAE: 0.0695 MSE 0.0267 SSIM 0.8122
# Training time elapesd per epoch 1m 56s
#
# Epoch 65/200
# ----------
# train Loss: 0.2303 MAE: 0.0578 MSE 0.0137 SSIM 0.8411
# valid Loss: 0.2759 MAE: 0.0671 MSE 0.0250 SSIM 0.8162
# Training time elapesd per epoch 1m 56s
#
# Epoch 66/200
# ----------
# train Loss: 0.2299 MAE: 0.0577 MSE 0.0136 SSIM 0.8414
# valid Loss: 0.3149 MAE: 0.0823 MSE 0.0329 SSIM 0.8003
# Training time elapesd per epoch 1m 56s
#
# Epoch 67/200
# ----------
# train Loss: 0.2294 MAE: 0.0576 MSE 0.0135 SSIM 0.8417
# valid Loss: 0.2805 MAE: 0.0678 MSE 0.0255 SSIM 0.8127
# Training time elapesd per epoch 1m 56s
#
# Epoch 68/200
# ----------
# train Loss: 0.2292 MAE: 0.0575 MSE 0.0135 SSIM 0.8418
# valid Loss: 0.2768 MAE: 0.0671 MSE 0.0252 SSIM 0.8155
# Training time elapesd per epoch 1m 56s
#
# Epoch 69/200
# ----------
# train Loss: 0.2286 MAE: 0.0573 MSE 0.0134 SSIM 0.8422
# valid Loss: 0.2831 MAE: 0.0693 MSE 0.0261 SSIM 0.8122
# Training time elapesd per epoch 1m 56s
#
# Epoch 70/200
# ----------
# train Loss: 0.2284 MAE: 0.0574 MSE 0.0134 SSIM 0.8423
# valid Loss: 0.2790 MAE: 0.0684 MSE 0.0258 SSIM 0.8152
# Training time elapesd per epoch 1m 56s
#
# Epoch 71/200
# ----------
# train Loss: 0.2279 MAE: 0.0572 MSE 0.0133 SSIM 0.8426
# valid Loss: 0.2789 MAE: 0.0687 MSE 0.0259 SSIM 0.8156
# Training time elapesd per epoch 1m 56s
#
# Epoch 72/200
# ----------
# train Loss: 0.2278 MAE: 0.0572 MSE 0.0133 SSIM 0.8427
# valid Loss: 0.3244 MAE: 0.0816 MSE 0.0340 SSIM 0.7912
# Training time elapesd per epoch 1m 56s
#
# Epoch 73/200
# ----------
# train Loss: 0.2272 MAE: 0.0570 MSE 0.0132 SSIM 0.8431
# valid Loss: 0.3069 MAE: 0.0770 MSE 0.0308 SSIM 0.8009
# Training time elapesd per epoch 1m 56s
#
# Epoch 74/200
# ----------
# train Loss: 0.2268 MAE: 0.0569 MSE 0.0132 SSIM 0.8433
# valid Loss: 0.2837 MAE: 0.0702 MSE 0.0268 SSIM 0.8133
# Training time elapesd per epoch 1m 56s
#
# Epoch 75/200
# ----------
# train Loss: 0.2267 MAE: 0.0569 MSE 0.0132 SSIM 0.8433
# valid Loss: 0.2820 MAE: 0.0689 MSE 0.0261 SSIM 0.8130
# Training time elapesd per epoch 1m 56s
#
# Epoch 76/200
# ----------
# train Loss: 0.2263 MAE: 0.0568 MSE 0.0131 SSIM 0.8436
# valid Loss: 0.2973 MAE: 0.0730 MSE 0.0278 SSIM 0.8034
# Training time elapesd per epoch 1m 56s
#
# Epoch 77/200
# ----------
# train Loss: 0.2261 MAE: 0.0568 MSE 0.0131 SSIM 0.8438
# valid Loss: 0.2923 MAE: 0.0748 MSE 0.0291 SSIM 0.8116
# Training time elapesd per epoch 1m 56s
#
# Epoch 78/200
# ----------
# train Loss: 0.2258 MAE: 0.0567 MSE 0.0130 SSIM 0.8439
# valid Loss: 0.3077 MAE: 0.0773 MSE 0.0310 SSIM 0.8006
# Training time elapesd per epoch 1m 56s
#
# Epoch 79/200
# ----------
# train Loss: 0.2257 MAE: 0.0567 MSE 0.0130 SSIM 0.8440
# valid Loss: 0.2881 MAE: 0.0707 MSE 0.0278 SSIM 0.8103
# Training time elapesd per epoch 1m 56s
#
# Epoch 80/200
# ----------
# train Loss: 0.2257 MAE: 0.0567 MSE 0.0130 SSIM 0.8440
# valid Loss: 0.2780 MAE: 0.0674 MSE 0.0254 SSIM 0.8148
# Training time elapesd per epoch 1m 56s
#
# Epoch 81/200
# ----------
# train Loss: 0.2253 MAE: 0.0566 MSE 0.0130 SSIM 0.8442
# valid Loss: 0.3329 MAE: 0.0851 MSE 0.0374 SSIM 0.7895
# Training time elapesd per epoch 1m 56s
#
# Epoch 82/200
# ----------
# train Loss: 0.2251 MAE: 0.0566 MSE 0.0130 SSIM 0.8444
# valid Loss: 0.2758 MAE: 0.0667 MSE 0.0251 SSIM 0.8160
# Training time elapesd per epoch 1m 56s
#
# Epoch 83/200
# ----------
# train Loss: 0.2247 MAE: 0.0564 MSE 0.0129 SSIM 0.8446
# valid Loss: 0.2764 MAE: 0.0672 MSE 0.0252 SSIM 0.8160
# Training time elapesd per epoch 1m 56s
#
# Epoch 84/200
# ----------
# train Loss: 0.2247 MAE: 0.0565 MSE 0.0129 SSIM 0.8446
# valid Loss: 0.2762 MAE: 0.0670 MSE 0.0253 SSIM 0.8161
# Training time elapesd per epoch 1m 56s
#
# Epoch 85/200
# ----------
# train Loss: 0.2244 MAE: 0.0564 MSE 0.0128 SSIM 0.8448
# valid Loss: 0.2785 MAE: 0.0676 MSE 0.0256 SSIM 0.8147
# Training time elapesd per epoch 1m 56s
#
# Epoch 86/200
# ----------
# train Loss: 0.2243 MAE: 0.0564 MSE 0.0128 SSIM 0.8449
# valid Loss: 0.2795 MAE: 0.0680 MSE 0.0257 SSIM 0.8142
# Training time elapesd per epoch 1m 56s
#
# Epoch 87/200
# ----------
# train Loss: 0.2242 MAE: 0.0563 MSE 0.0128 SSIM 0.8450
# valid Loss: 0.2753 MAE: 0.0667 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 88/200
# ----------
# train Loss: 0.2239 MAE: 0.0562 MSE 0.0128 SSIM 0.8451
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 89/200
# ----------
# train Loss: 0.2238 MAE: 0.0563 MSE 0.0128 SSIM 0.8452
# valid Loss: 0.2757 MAE: 0.0668 MSE 0.0251 SSIM 0.8162
# Training time elapesd per epoch 1m 56s
#
# Epoch 90/200
# ----------
# train Loss: 0.2238 MAE: 0.0562 MSE 0.0128 SSIM 0.8452
# valid Loss: 0.2754 MAE: 0.0667 MSE 0.0251 SSIM 0.8164
# Training time elapesd per epoch 1m 56s
#
# Epoch 91/200
# ----------
# train Loss: 0.2236 MAE: 0.0562 MSE 0.0127 SSIM 0.8453
# valid Loss: 0.2790 MAE: 0.0683 MSE 0.0259 SSIM 0.8152
# Training time elapesd per epoch 1m 56s
#
# Epoch 92/200
# ----------
# train Loss: 0.2234 MAE: 0.0561 MSE 0.0127 SSIM 0.8455
# valid Loss: 0.2762 MAE: 0.0671 MSE 0.0252 SSIM 0.8161
# Training time elapesd per epoch 1m 56s
#
# Epoch 93/200
# ----------
# train Loss: 0.2233 MAE: 0.0561 MSE 0.0127 SSIM 0.8456
# valid Loss: 0.2753 MAE: 0.0669 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 94/200
# ----------
# train Loss: 0.2232 MAE: 0.0561 MSE 0.0127 SSIM 0.8456
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 95/200
# ----------
# train Loss: 0.2231 MAE: 0.0561 MSE 0.0127 SSIM 0.8457
# valid Loss: 0.2799 MAE: 0.0688 MSE 0.0262 SSIM 0.8152
# Training time elapesd per epoch 1m 56s
#
# Epoch 96/200
# ----------
# train Loss: 0.2227 MAE: 0.0560 MSE 0.0126 SSIM 0.8459
# valid Loss: 0.2764 MAE: 0.0673 MSE 0.0254 SSIM 0.8162
# Training time elapesd per epoch 1m 57s
#
# Epoch 97/200
# ----------
# train Loss: 0.2227 MAE: 0.0560 MSE 0.0126 SSIM 0.8459
# valid Loss: 0.2767 MAE: 0.0671 MSE 0.0252 SSIM 0.8156
# Training time elapesd per epoch 1m 56s
#
# Epoch 98/200
# ----------
# train Loss: 0.2228 MAE: 0.0560 MSE 0.0127 SSIM 0.8459
# valid Loss: 0.2760 MAE: 0.0671 MSE 0.0255 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 99/200
# ----------
# train Loss: 0.2227 MAE: 0.0560 MSE 0.0126 SSIM 0.8459
# valid Loss: 0.2761 MAE: 0.0671 MSE 0.0253 SSIM 0.8163
# Training time elapesd per epoch 1m 56s
#
# Epoch 100/200
# ----------
# train Loss: 0.2226 MAE: 0.0559 MSE 0.0126 SSIM 0.8459
# valid Loss: 0.2755 MAE: 0.0667 MSE 0.0252 SSIM 0.8164
# Training time elapesd per epoch 1m 56s
#
# Epoch 101/200
# ----------
# train Loss: 0.2223 MAE: 0.0559 MSE 0.0126 SSIM 0.8462
# valid Loss: 0.2762 MAE: 0.0667 MSE 0.0252 SSIM 0.8157
# Training time elapesd per epoch 1m 57s
#
# Epoch 102/200
# ----------
# train Loss: 0.2224 MAE: 0.0559 MSE 0.0126 SSIM 0.8461
# valid Loss: 0.2754 MAE: 0.0667 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 103/200
# ----------
# train Loss: 0.2222 MAE: 0.0559 MSE 0.0126 SSIM 0.8462
# valid Loss: 0.2769 MAE: 0.0676 MSE 0.0256 SSIM 0.8163
# Training time elapesd per epoch 1m 56s
#
# Epoch 104/200
# ----------
# train Loss: 0.2222 MAE: 0.0559 MSE 0.0126 SSIM 0.8462
# valid Loss: 0.2774 MAE: 0.0674 MSE 0.0254 SSIM 0.8154
# Training time elapesd per epoch 1m 56s
#
# Epoch 105/200
# ----------
# train Loss: 0.2222 MAE: 0.0559 MSE 0.0126 SSIM 0.8463
# valid Loss: 0.2779 MAE: 0.0673 MSE 0.0255 SSIM 0.8149
# Training time elapesd per epoch 1m 56s
#
# Epoch 106/200
# ----------
# train Loss: 0.2222 MAE: 0.0559 MSE 0.0126 SSIM 0.8462
# valid Loss: 0.2790 MAE: 0.0685 MSE 0.0260 SSIM 0.8154
# Training time elapesd per epoch 1m 56s
#
# Epoch 107/200
# ----------
# train Loss: 0.2219 MAE: 0.0558 MSE 0.0125 SSIM 0.8464
# valid Loss: 0.2762 MAE: 0.0669 MSE 0.0252 SSIM 0.8159
# Training time elapesd per epoch 1m 56s
#
# Epoch 108/200
# ----------
# train Loss: 0.2219 MAE: 0.0558 MSE 0.0125 SSIM 0.8464
# valid Loss: 0.2809 MAE: 0.0695 MSE 0.0265 SSIM 0.8150
# Training time elapesd per epoch 1m 56s
#
# Epoch 109/200
# ----------
# train Loss: 0.2218 MAE: 0.0558 MSE 0.0125 SSIM 0.8465
# valid Loss: 0.2759 MAE: 0.0670 MSE 0.0253 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 110/200
# ----------
# train Loss: 0.2219 MAE: 0.0558 MSE 0.0125 SSIM 0.8464
# valid Loss: 0.2750 MAE: 0.0667 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 111/200
# ----------
# train Loss: 0.2217 MAE: 0.0557 MSE 0.0125 SSIM 0.8465
# valid Loss: 0.2765 MAE: 0.0668 MSE 0.0253 SSIM 0.8156
# Training time elapesd per epoch 1m 56s
#
# Epoch 112/200
# ----------
# train Loss: 0.2219 MAE: 0.0558 MSE 0.0125 SSIM 0.8464
# valid Loss: 0.2759 MAE: 0.0671 MSE 0.0254 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 113/200
# ----------
# train Loss: 0.2216 MAE: 0.0557 MSE 0.0125 SSIM 0.8466
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 114/200
# ----------
# train Loss: 0.2217 MAE: 0.0557 MSE 0.0125 SSIM 0.8466
# valid Loss: 0.2768 MAE: 0.0675 MSE 0.0256 SSIM 0.8163
# Training time elapesd per epoch 1m 56s
#
# Epoch 115/200
# ----------
# train Loss: 0.2216 MAE: 0.0557 MSE 0.0125 SSIM 0.8466
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0251 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 116/200
# ----------
# train Loss: 0.2216 MAE: 0.0557 MSE 0.0125 SSIM 0.8466
# valid Loss: 0.2764 MAE: 0.0672 MSE 0.0255 SSIM 0.8162
# Training time elapesd per epoch 1m 56s
#
# Epoch 117/200
# ----------
# train Loss: 0.2215 MAE: 0.0557 MSE 0.0125 SSIM 0.8467
# valid Loss: 0.2753 MAE: 0.0666 MSE 0.0253 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 118/200
# ----------
# train Loss: 0.2216 MAE: 0.0557 MSE 0.0125 SSIM 0.8466
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 119/200
# ----------
# train Loss: 0.2215 MAE: 0.0557 MSE 0.0125 SSIM 0.8467
# valid Loss: 0.2756 MAE: 0.0669 MSE 0.0253 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 120/200
# ----------
# train Loss: 0.2215 MAE: 0.0557 MSE 0.0125 SSIM 0.8467
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 121/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2756 MAE: 0.0666 MSE 0.0252 SSIM 0.8163
# Training time elapesd per epoch 1m 56s
#
# Epoch 122/200
# ----------
# train Loss: 0.2214 MAE: 0.0557 MSE 0.0125 SSIM 0.8467
# valid Loss: 0.2747 MAE: 0.0664 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 57s
#
# Epoch 123/200
# ----------
# train Loss: 0.2214 MAE: 0.0556 MSE 0.0125 SSIM 0.8468
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 124/200
# ----------
# train Loss: 0.2214 MAE: 0.0557 MSE 0.0125 SSIM 0.8468
# valid Loss: 0.2762 MAE: 0.0670 MSE 0.0254 SSIM 0.8163
# Training time elapesd per epoch 1m 56s
#
# Epoch 125/200
# ----------
# train Loss: 0.2212 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2753 MAE: 0.0667 MSE 0.0253 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 126/200
# ----------
# train Loss: 0.2214 MAE: 0.0557 MSE 0.0125 SSIM 0.8468
# valid Loss: 0.2761 MAE: 0.0669 MSE 0.0252 SSIM 0.8160
# Training time elapesd per epoch 1m 56s
#
# Epoch 127/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 128/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2748 MAE: 0.0665 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 129/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 130/200
# ----------
# train Loss: 0.2212 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2761 MAE: 0.0671 MSE 0.0255 SSIM 0.8164
# Training time elapesd per epoch 1m 56s
#
# Epoch 131/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 132/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 57s
#
# Epoch 133/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2755 MAE: 0.0668 MSE 0.0253 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 134/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2755 MAE: 0.0668 MSE 0.0253 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 135/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 136/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 137/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 57s
#
# Epoch 138/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0125 SSIM 0.8470
# valid Loss: 0.2753 MAE: 0.0665 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 139/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2755 MAE: 0.0667 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 140/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2759 MAE: 0.0670 MSE 0.0253 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 141/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2748 MAE: 0.0665 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 142/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8469
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 57s
#
# Epoch 143/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 144/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 145/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 146/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 147/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 57s
#
# Epoch 148/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 149/200
# ----------
# train Loss: 0.2209 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 150/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 151/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2748 MAE: 0.0664 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 152/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 57s
#
# Epoch 153/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 154/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 155/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2756 MAE: 0.0668 MSE 0.0254 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 156/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 157/200
# ----------
# train Loss: 0.2211 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 158/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 159/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2754 MAE: 0.0668 MSE 0.0253 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 160/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 161/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 162/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0666 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 163/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 164/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 165/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 166/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 167/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0253 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 168/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2748 MAE: 0.0665 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 169/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 170/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 171/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 172/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0251 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 173/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2752 MAE: 0.0665 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 174/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 175/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 176/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 177/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2756 MAE: 0.0668 MSE 0.0253 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 178/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 179/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2749 MAE: 0.0666 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 180/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 181/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0666 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 182/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 183/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0667 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 184/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2752 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 185/200
# ----------
# train Loss: 0.2207 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2752 MAE: 0.0665 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 186/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 187/200
# ----------
# train Loss: 0.2209 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 188/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 189/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2752 MAE: 0.0666 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 190/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2752 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 191/200
# ----------
# train Loss: 0.2210 MAE: 0.0556 MSE 0.0124 SSIM 0.8470
# valid Loss: 0.2748 MAE: 0.0664 MSE 0.0251 SSIM 0.8168
# Training time elapesd per epoch 1m 56s
#
# Epoch 192/200
# ----------
# train Loss: 0.2208 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 193/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 194/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2750 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 195/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2751 MAE: 0.0665 MSE 0.0252 SSIM 0.8166
# Training time elapesd per epoch 1m 56s
#
# Epoch 196/200
# ----------
# train Loss: 0.2209 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2754 MAE: 0.0667 MSE 0.0252 SSIM 0.8165
# Training time elapesd per epoch 1m 56s
#
# Epoch 197/200
# ----------
# train Loss: 0.2208 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0665 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 198/200
# ----------
# train Loss: 0.2206 MAE: 0.0555 MSE 0.0124 SSIM 0.8472
# valid Loss: 0.2750 MAE: 0.0666 MSE 0.0252 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 199/200
# ----------
# train Loss: 0.2209 MAE: 0.0555 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0251 SSIM 0.8167
# Training time elapesd per epoch 1m 56s
#
# Epoch 200/200
# ----------
# train Loss: 0.2209 MAE: 0.0556 MSE 0.0124 SSIM 0.8471
# valid Loss: 0.2749 MAE: 0.0664 MSE 0.0251 SSIM 0.8166
# Training time elapesd per epoch 1m 56s

# %%
plt.figure(figsize=[8,5])

plt.plot(range(1,len(train_losses)+1),train_losses,'r--',label = 'Training loss')
plt.plot(range(1,len(val_losses)+1),val_losses,'b-',label = 'Validation loss')
plt.title('Training and validation loss', fontsize=15)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.ylim([0, 1.0])
plt.legend(loc="upper right")

plt.show()

# %%
plt.clf()
plt.figure(figsize=[8,5])

plt.plot(range(1,len(train_mae_losses)+1),train_mae_losses,'r--',label = 'Training mae')
plt.plot(range(1,len(val_mae_losses)+1),val_mae_losses,'b-',label = 'Validation mae')
plt.title('Training and validation Mean Absolute Error', fontsize=15)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('Mean Absolute Error', fontsize=15)
plt.ylim([0, 0.4])
plt.legend(loc="upper right")

plt.show()

# %%
plt.clf()
plt.figure(figsize=[8,5])

plt.plot(range(1,len(train_mse_losses)+1),train_mse_losses,'r--',label = 'Training mse')
plt.plot(range(1,len(val_mse_losses)+1),val_mse_losses,'b-',label = 'Validation mse')
plt.title('Training and validation Mean Squared Error', fontsize=15)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('Mean Squared Error', fontsize=15)
plt.ylim([0, 0.4])
plt.legend(loc="upper right")

plt.show()

# %%
plt.clf()
plt.figure(figsize=[8,5])

plt.plot(range(1,len(train_ssim_losses)+1),train_ssim_losses,'r--',label = 'Training ssim')
plt.plot(range(1,len(val_ssim_losses)+1),val_ssim_losses,'b-',label = 'Validation ssim')
plt.title('Training and validation Structural Similarity Index Metric', fontsize=15)
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('Structural Similarity Index Metric', fontsize=15)
plt.ylim([0.6, 0.9])
plt.legend(loc="upper right")

plt.show()

# %%
def evaluate(model, test_loader):
    since = time.time()
    model.eval()
    
    test_mae = 0.0
    test_mse = 0.0
    test_ssim = 0.0
    test_loss = 0.0

    with torch.no_grad():
        for image, label in test_loader:
            image, label = image.cuda(), label.cuda()
            output = model(image)
            mae_loss = F.l1_loss(output, label)
            mse_loss = F.mse_loss(output, label)
            ssim_loss = ssim(output, label)
            loss = mae_loss + mse_loss + (1 - ssim_loss)
            
            test_mae += mae_loss.detach()
            test_mse += mse_loss.detach()
            test_ssim += ssim_loss.detach()
            test_loss += loss.detach()
    
    epoch_test_mae = test_mae / len(test_loader.dataset) * BATCH_SIZE
    epoch_test_mse = test_mse / len(test_loader.dataset) * BATCH_SIZE
    epoch_test_ssim = test_ssim / len(test_loader.dataset) * BATCH_SIZE
    epoch_test_loss = test_loss / len(test_loader.dataset) * BATCH_SIZE
    
    time_elapsed = time.time() - since
    print('Loss: {:.4f} MAE: {:.4f} MSE {:.4f} SSIM {:.4f}'.format(
        epoch_test_loss, epoch_test_mae, epoch_test_mse, epoch_test_ssim))
    print('Total time elapesd of test data {:.0f}m {:.0f}s'.format(
                    time_elapsed // 60, time_elapsed % 60))
    return epoch_test_loss, epoch_test_mae, epoch_test_mse, epoch_test_ssim

# %%
PATH = "./weights/Tomography_CNN.pt"

# %%
torch.save(model_ft.state_dict(), PATH)

# %%
device = torch.device("cuda")
trained_model = torch.nn.DataParallel(Tomography_CNN(), device_ids=[0, 1, 2, 3])
#trained_model = Tomography_CNN()
trained_model.load_state_dict(torch.load(PATH))
trained_model.to(device)
# Out:
# DataParallel(
#   (module): Tomography_CNN(
#     (layers): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64, bias=False)
#           (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64, bias=False)
#           (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0), dilation=1, ceil_mode=False)
#       (3): Sequential(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64, bias=False)
#           (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0), dilation=1, ceil_mode=False)
#       (5): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128, bias=False)
#           (pointwise): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0), dilation=1, ceil_mode=False)
#       (7): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (pointwise): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (pointwise): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (8): MaxPool2d(kernel_size=(2, 5), stride=(2, 5), padding=(0, 0), dilation=1, ceil_mode=False)
#       (9): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (pointwise): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (pointwise): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (10): Dropout(p=0.5, inplace=False)
#       (11): Upsample(scale_factor=(2.0, 5.0), mode=nearest)
#       (12): ConvTranspose2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): Sequential(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(1024, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1024, bias=False)
#           (pointwise): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (pointwise): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (14): Upsample(scale_factor=(2.0, 1.0), mode=nearest)
#       (15): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (16): Sequential(
#         (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512, bias=False)
#           (pointwise): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (17): Upsample(scale_factor=(2.0, 2.0), mode=nearest)
#       (18): ConvTranspose2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): Sequential(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=256, bias=False)
#           (pointwise): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (20): Upsample(scale_factor=(2.0, 1.0), mode=nearest)
#       (21): ConvTranspose2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): Sequential(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): ReLU(inplace=True)
#         (2): SeparableConv2d(
#           (depthwise): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128, bias=False)
#           (pointwise): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#         (5): SeparableConv2d(
#           (depthwise): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64, bias=False)
#           (pointwise): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#       (23): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#       (24): Sigmoid()
#     )
#   )
# )

# %%
test_loss, test_mae, test_mse, test_ssim= evaluate(trained_model, test_loader)
# Out:
# Loss: 0.2755 MAE: 0.0669 MSE 0.0253 SSIM 0.8166
# Total time elapesd of test data 0m 9s

# %%
test_loss, test_mae, test_mse, test_ssim
# Out:
# (tensor(0.2755, device='cuda:0'),
#  tensor(0.0669, device='cuda:0'),
#  tensor(0.0253, device='cuda:0'),
#  tensor(0.8166, device='cuda:0'))

# %%
def perc_clip_val(data,perc=100):
    # return clipping value by percent clip, does not apply clipping
    # data: array to clip
    # perc: percent value
    # output: min/max clip values
    mperc=(100.-perc)*0.01*0.5
    tmp=np.sort(data.flatten())
    minloc=int(len(tmp)*mperc)
    maxloc=len(tmp)-minloc-1
    clipmin=tmp[minloc]
    clipmax=tmp[maxloc]
    return clipmin,clipmax

# %%
def make_plot(y ,prediction, perc=97):
    #clipmin,clipmax = perc_clip_val(x, perc)
    plt.figure(figsize=[16,3])
    # input seismogram - one shotgather
    #plt.subplot(1,3,1)
    #plt.imshow(np.clip(x,clipmin,clipmax), aspect='auto',cmap='gray_r')
    # true velocity model
    plt.subplot(1,2,1)
    plt.imshow(y.T, vmin=1.5, vmax=5.0)
    plt.xticks(np.arange(0, 320, 40), np.arange(0, 32, 4))
    plt.yticks(np.arange(0, 50, 20), np.arange(0, 5, 2))
    plt.xlabel("Distance (km)",fontsize=10)
    plt.ylabel("Depth (km)",fontsize=8)
    plt.colorbar(shrink=0.325, aspect=10, pad=0.01, label="km/s")
    # predicted velocity model
    plt.subplot(1,2,2)
    plt.imshow(prediction.T, vmin=1.5, vmax=5.0)
    plt.xticks(np.arange(0, 320, 40), np.arange(0, 32, 4))
    plt.yticks(np.arange(0, 50, 20), np.arange(0, 5, 2))
    plt.xlabel("Distance (km)",fontsize=10)
    plt.ylabel("Depth (km)",fontsize=8)
    plt.colorbar(shrink=0.325, aspect=10, pad=0.01, label="km/s")

# %%
def plot_prediction(model, test_loader, ibatch=0):
    model.eval()
    
    with torch.no_grad():
        i = 0
        for image, label in test_loader:
            i += 1
            image, label = image.cuda(), label.cuda()
            output = model(image)
            image, label = image.cpu(), label.cpu()
            output = output.cpu()
            make_plot(label[ibatch].detach().numpy() ,output[ibatch].detach().numpy())
            label[ibatch].detach().numpy().astype(np.float32).tofile("./pred/CNN/label_test%05d.bin"%(BATCH_SIZE * i))
            output[ibatch].detach().numpy().astype(np.float32).tofile("./pred/CNN/pred_test%05d.bin"%(BATCH_SIZE * i))

# %%
plot_prediction(trained_model, test_loader, ibatch=0)
# Out:
# /tmp/ipykernel_143061/3982833261.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=[16,3])

# %%
figsize=[8,3]

for i in range(1,51):
    plt.figure(figsize=figsize)
    vel = np.fromfile("./pred/CNN/label_test%05d.bin"%(BATCH_SIZE * i),dtype=np.float32)
    vel.shape=(320,50)
    plt.imshow(vel.T,vmin=1.5,vmax=5.0)
plt.show()
# Out:
# /tmp/ipykernel_143061/840854535.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=figsize)
