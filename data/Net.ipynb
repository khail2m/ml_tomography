# %%
import numpy as np
from torchsummary import summary

# %%
from Net import Tomography_CNN

# %%
net = Tomography_CNN()

# %%
nshot=200
nx=320
ny=50

input_size = (1,nx,nshot)

# %%
summary(net, input_size, batch_size=20, device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [20, 64, 320, 200]           3,200
#        BatchNorm2d-2         [20, 64, 320, 200]             128
#               ReLU-3         [20, 64, 320, 200]               0
#             Conv2d-4         [20, 64, 320, 200]           1,600
#             Conv2d-5         [20, 64, 320, 200]           4,096
#    SeparableConv2d-6         [20, 64, 320, 200]               0
#        BatchNorm2d-7         [20, 64, 320, 200]             128
#               ReLU-8         [20, 64, 320, 200]               0
#             Conv2d-9         [20, 64, 320, 200]           1,600
#            Conv2d-10         [20, 64, 320, 200]           4,096
#   SeparableConv2d-11         [20, 64, 320, 200]               0
#         MaxPool2d-12         [20, 64, 160, 100]               0
#       BatchNorm2d-13         [20, 64, 160, 100]             128
# ...

# %%
from ConvNet import Tomography_nCNN

# %%
net = Tomography_nCNN()

# %%
summary(net, input_size, batch_size=20, device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [20, 64, 320, 200]           3,200
#        BatchNorm2d-2         [20, 64, 320, 200]             128
#               ReLU-3         [20, 64, 320, 200]               0
#             Conv2d-4         [20, 64, 320, 200]         102,400
#        BatchNorm2d-5         [20, 64, 320, 200]             128
#               ReLU-6         [20, 64, 320, 200]               0
#             Conv2d-7         [20, 64, 320, 200]         102,400
#          MaxPool2d-8         [20, 64, 160, 100]               0
#        BatchNorm2d-9         [20, 64, 160, 100]             128
#              ReLU-10         [20, 64, 160, 100]               0
#            Conv2d-11        [20, 128, 160, 100]         204,800
#       BatchNorm2d-12        [20, 128, 160, 100]             256
#              ReLU-13        [20, 128, 160, 100]               0
# ...
